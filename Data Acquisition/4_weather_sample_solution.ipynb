# %%
import pandas as pd
import requests
from datetime import datetime

# using colab secrets to store our passwords and keys
#from google.colab import userdata

# %% [markdown]
# # Making the API call and viewing the json
#
# If you want to search for the city by name and country instead of latitude and longitude, try using the [Geocoding API](https://openweathermap.org/api/geocoding-api).

# %%
# Berlin
latitude = 52.520008
longitude = 13.404954

API_key = "89b4a954f2f955292f6b3136080e5184"

# check out the docs for more info on making an api call https://openweathermap.org/forecast5
url = (f"https://api.openweathermap.org/data/2.5/forecast?lat={latitude}&lon={longitude}&appid={API_key}&units=metric")

response = requests.get(url)
json = response.json()

json
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1744632000,
#    'main': {'temp': 18.53,
#     'feels_like': 17.87,
#     'temp_min': 18.53,
#     'temp_max': 19.52,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1005,
#     'humidity': 55,
#     'temp_kf': -0.99},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 63},
#    'wind': {'speed': 3.81, 'deg': 282, 'gust': 5.11},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-14 12:00:00'},
#   {'dt': 1744642800,
#    'main': {'temp': 20.22,
#     'feels_like': 19.45,
#     'temp_min': 20.22,
#     'temp_max': 21.32,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1004,
#     'humidity': 44,
#     'temp_kf': -1.1},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 68},
#    'wind': {'speed': 2.07, 'deg': 253, 'gust': 2.44},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-14 15:00:00'},
#   {'dt': 1744653600,
#    'main': {'temp': 17.22,
#     'feels_like': 16.28,
#     'temp_min': 17.22,
#     'temp_max': 17.22,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1004,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 48},
#    'wind': {'speed': 2.56, 'deg': 25, 'gust': 4.67},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-14 18:00:00'},
#   {'dt': 1744664400,
#    'main': {'temp': 16.08,
#     'feels_like': 15.21,
#     'temp_min': 16.08,
#     'temp_max': 16.08,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1005,
#     'humidity': 56,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 44},
#    'wind': {'speed': 2.96, 'deg': 70, 'gust': 6.91},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-04-14 21:00:00'},
#   {'dt': 1744675200,
#    'main': {'temp': 9.83,
#     'feels_like': 7.85,
#     'temp_min': 9.83,
#     'temp_max': 9.83,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1003,
#     'humidity': 64,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 37},
#    'wind': {'speed': 3.88, 'deg': 83, 'gust': 11.09},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-04-15 00:00:00'},
#   {'dt': 1744686000,
#    'main': {'temp': 12.55,
#     'feels_like': 11.71,
#     'temp_min': 12.55,
#     'temp_max': 12.55,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1002,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 18},
#    'wind': {'speed': 3.82, 'deg': 89, 'gust': 9.64},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-04-15 03:00:00'},
#   {'dt': 1744696800,
#    'main': {'temp': 13.8,
#     'feels_like': 13.17,
#     'temp_min': 13.8,
#     'temp_max': 13.8,
#     'pressure': 1006,
#     'sea_level': 1006,
#     'grnd_level': 1000,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 49},
#    'wind': {'speed': 4.52, 'deg': 87, 'gust': 10.98},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-15 06:00:00'},
#   {'dt': 1744707600,
#    'main': {'temp': 15.56,
#     'feels_like': 15,
#     'temp_min': 15.56,
#     'temp_max': 15.56,
#     'pressure': 1004,
#     'sea_level': 1004,
#     'grnd_level': 999,
#     'humidity': 70,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 67},
#    'wind': {'speed': 4.73, 'deg': 107, 'gust': 11.35},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-15 09:00:00'},
#   {'dt': 1744718400,
#    'main': {'temp': 14.73,
#     'feels_like': 14.3,
#     'temp_min': 14.73,
#     'temp_max': 14.73,
#     'pressure': 1004,
#     'sea_level': 1004,
#     'grnd_level': 998,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 84},
#    'wind': {'speed': 5.86, 'deg': 117, 'gust': 12.21},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.14},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-15 12:00:00'},
#   {'dt': 1744729200,
#    'main': {'temp': 14.14,
#     'feels_like': 13.83,
#     'temp_min': 14.14,
#     'temp_max': 14.14,
#     'pressure': 1003,
#     'sea_level': 1003,
#     'grnd_level': 997,
#     'humidity': 85,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.54, 'deg': 110, 'gust': 9.59},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-15 15:00:00'},
#   {'dt': 1744740000,
#    'main': {'temp': 13.64,
#     'feels_like': 13.36,
#     'temp_min': 13.64,
#     'temp_max': 13.64,
#     'pressure': 1003,
#     'sea_level': 1003,
#     'grnd_level': 997,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.46, 'deg': 119, 'gust': 8.17},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.22},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-15 18:00:00'},
#   {'dt': 1744750800,
#    'main': {'temp': 13.02,
#     'feels_like': 12.73,
#     'temp_min': 13.02,
#     'temp_max': 13.02,
#     'pressure': 1003,
#     'sea_level': 1003,
#     'grnd_level': 997,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.13, 'deg': 129, 'gust': 5.22},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-04-15 21:00:00'},
#   {'dt': 1744761600,
#    'main': {'temp': 11.54,
#     'feels_like': 11.2,
#     'temp_min': 11.54,
#     'temp_max': 11.54,
#     'pressure': 1004,
#     'sea_level': 1004,
#     'grnd_level': 998,
#     'humidity': 94,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 1.74, 'deg': 188, 'gust': 2.34},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-04-16 00:00:00'},
#   {'dt': 1744772400,
#    'main': {'temp': 11.32,
#     'feels_like': 10.96,
#     'temp_min': 11.32,
#     'temp_max': 11.32,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 1000,
#     'humidity': 94,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.73, 'deg': 238, 'gust': 2.16},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-04-16 03:00:00'},
#   {'dt': 1744783200,
#    'main': {'temp': 13,
#     'feels_like': 12.57,
#     'temp_min': 13,
#     'temp_max': 13,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1002,
#     'humidity': 85,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 51},
#    'wind': {'speed': 1.99, 'deg': 230, 'gust': 3.69},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-16 06:00:00'},
#   {'dt': 1744794000,
#    'main': {'temp': 18.54,
#     'feels_like': 18.04,
#     'temp_min': 18.54,
#     'temp_max': 18.54,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1004,
#     'humidity': 61,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 3},
#    'wind': {'speed': 1.9, 'deg': 312, 'gust': 2.87},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-16 09:00:00'},
#   {'dt': 1744804800,
#    'main': {'temp': 22.79,
#     'feels_like': 22.27,
#     'temp_min': 22.79,
#     'temp_max': 22.79,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1004,
#     'humidity': 44,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 18},
#    'wind': {'speed': 0.25, 'deg': 45, 'gust': 0.44},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-16 12:00:00'},
#   {'dt': 1744815600,
#    'main': {'temp': 23.39,
#     'feels_like': 22.86,
#     'temp_min': 23.39,
#     'temp_max': 23.39,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1004,
#     'humidity': 41,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 6},
#    'wind': {'speed': 2.47, 'deg': 80, 'gust': 3.37},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-16 15:00:00'},
#   {'dt': 1744826400,
#    'main': {'temp': 20.55,
#     'feels_like': 20.12,
#     'temp_min': 20.55,
#     'temp_max': 20.55,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1003,
#     'humidity': 56,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 37},
#    'wind': {'speed': 4.39, 'deg': 59, 'gust': 8.35},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-16 18:00:00'},
#   {'dt': 1744837200,
#    'main': {'temp': 18.38,
#     'feels_like': 18.13,
#     'temp_min': 18.38,
#     'temp_max': 18.38,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1003,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 96},
#    'wind': {'speed': 4.84, 'deg': 81, 'gust': 11.75},
#    'visibility': 10000,
#    'pop': 0.62,
#    'rain': {'3h': 0.33},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-04-16 21:00:00'},
#   {'dt': 1744848000,
#    'main': {'temp': 16.45,
#     'feels_like': 16.11,
#     'temp_min': 16.45,
#     'temp_max': 16.45,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1002,
#     'humidity': 75,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 80},
#    'wind': {'speed': 3.81, 'deg': 101, 'gust': 11.45},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-04-17 00:00:00'},
#   {'dt': 1744858800,
#    'main': {'temp': 14.71,
#     'feels_like': 14.25,
#     'temp_min': 14.71,
#     'temp_max': 14.71,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 1002,
#     'humidity': 77,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 12},
#    'wind': {'speed': 2.71, 'deg': 116, 'gust': 9.18},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-04-17 03:00:00'},
#   {'dt': 1744869600,
#    'main': {'temp': 15.07,
#     'feels_like': 14.54,
#     'temp_min': 15.07,
#     'temp_max': 15.07,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1003,
#     'humidity': 73,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 43},
#    'wind': {'speed': 2.35, 'deg': 172, 'gust': 3.47},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-17 06:00:00'},
#   {'dt': 1744880400,
#    'main': {'temp': 15.87,
#     'feels_like': 15.39,
#     'temp_min': 15.87,
#     'temp_max': 15.87,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1004,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 83},
#    'wind': {'speed': 4.93, 'deg': 251, 'gust': 4.52},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-17 09:00:00'},
#   {'dt': 1744891200,
#    'main': {'temp': 11.79,
#     'feels_like': 11.06,
#     'temp_min': 11.79,
#     'temp_max': 11.79,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1007,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 90},
#    'wind': {'speed': 4.76, 'deg': 250, 'gust': 5.52},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-17 12:00:00'},
#   {'dt': 1744902000,
#    'main': {'temp': 10.82,
#     'feels_like': 9.99,
#     'temp_min': 10.82,
#     'temp_max': 10.82,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1009,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.98, 'deg': 266, 'gust': 5.09},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-17 15:00:00'},
#   {'dt': 1744912800,
#    'main': {'temp': 9.97,
#     'feels_like': 8.02,
#     'temp_min': 9.97,
#     'temp_max': 9.97,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1009,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.87, 'deg': 298, 'gust': 5.64},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-17 18:00:00'},
#   {'dt': 1744923600,
#    'main': {'temp': 9.75,
#     'feels_like': 8.75,
#     'temp_min': 9.75,
#     'temp_max': 9.75,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1010,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.19, 'deg': 299, 'gust': 2.71},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-04-17 21:00:00'},
#   {'dt': 1744934400,
#    'main': {'temp': 9.68,
#     'feels_like': 8.56,
#     'temp_min': 9.68,
#     'temp_max': 9.68,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1010,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.33, 'deg': 339, 'gust': 3},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-04-18 00:00:00'},
#   {'dt': 1744945200,
#    'main': {'temp': 10.01,
#     'feels_like': 9.21,
#     'temp_min': 10.01,
#     'temp_max': 10.01,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1009,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.53, 'deg': 2, 'gust': 2.17},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-04-18 03:00:00'},
#   {'dt': 1744956000,
#    'main': {'temp': 10.19,
#     'feels_like': 9.41,
#     'temp_min': 10.19,
#     'temp_max': 10.19,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1010,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.87, 'deg': 32, 'gust': 2.25},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-18 06:00:00'},
#   {'dt': 1744966800,
#    'main': {'temp': 11.79,
#     'feels_like': 10.98,
#     'temp_min': 11.79,
#     'temp_max': 11.79,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1009,
#     'humidity': 75,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 0.91, 'deg': 22, 'gust': 0.81},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-18 09:00:00'},
#   {'dt': 1744977600,
#    'main': {'temp': 11.44,
#     'feels_like': 10.73,
#     'temp_min': 11.44,
#     'temp_max': 11.44,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1009,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 0.26, 'deg': 173, 'gust': 0.48},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.22},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-18 12:00:00'},
#   {'dt': 1744988400,
#    'main': {'temp': 10.79,
#     'feels_like': 10.22,
#     'temp_min': 10.79,
#     'temp_max': 10.79,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1008,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.48, 'deg': 251, 'gust': 1.74},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 1.28},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-18 15:00:00'},
#   {'dt': 1744999200,
#    'main': {'temp': 10.29,
#     'feels_like': 9.7,
#     'temp_min': 10.29,
#     'temp_max': 10.29,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1009,
#     'humidity': 89,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.91, 'deg': 270, 'gust': 2.79},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.22},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-18 18:00:00'},
#   {'dt': 1745010000,
#    'main': {'temp': 10.01,
#     'feels_like': 9.39,
#     'temp_min': 10.01,
#     'temp_max': 10.01,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1008,
#     'humidity': 89,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.82, 'deg': 253, 'gust': 3},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-04-18 21:00:00'},
#   {'dt': 1745020800,
#    'main': {'temp': 9.67,
#     'feels_like': 8.95,
#     'temp_min': 9.67,
#     'temp_max': 9.67,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1008,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.83, 'deg': 263, 'gust': 3.64},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-04-19 00:00:00'},
#   {'dt': 1745031600,
#    'main': {'temp': 8.69,
#     'feels_like': 8.69,
#     'temp_min': 8.69,
#     'temp_max': 8.69,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1007,
#     'humidity': 91,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.18, 'deg': 221, 'gust': 1.4},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-04-19 03:00:00'},
#   {'dt': 1745042400,
#    'main': {'temp': 9.81,
#     'feels_like': 9.27,
#     'temp_min': 9.81,
#     'temp_max': 9.81,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1007,
#     'humidity': 84,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.66, 'deg': 191, 'gust': 2.44},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-19 06:00:00'},
#   {'dt': 1745053200,
#    'main': {'temp': 14.27,
#     'feels_like': 13.35,
#     'temp_min': 14.27,
#     'temp_max': 14.27,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1006,
#     'humidity': 61,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.88, 'deg': 215, 'gust': 2.5},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-19 09:00:00'}],
#  'city': {'id': 6545310,
#   'name': 'Mitte',
#   'coord': {'lat': 52.52, 'lon': 13.405},
#   'country': 'DE',
#   'population': 329078,
#   'timezone': 7200,
#   'sunrise': 1744603832,
#   'sunset': 1744653738}}

# %% [markdown]
# # Exploring the json
# Remember, if you want to know more about any of the information in the json, or you're unsure what a key is, check out the [open weather docs](https://openweathermap.org/forecast5).
#
# First, let's look at the keys

# %%
json.keys()
# Out:
# dict_keys(['cod', 'message', 'cnt', 'list', 'city'])

# %%
json["cod"]
# Out:
# '200'

# %%
json["message"]
# Out:
# 0

# %%
json["cnt"]
# Out:
# 40

# %%
json["list"]
# Out:
# [{'dt': 1744632000,
#   'main': {'temp': 18.53,
#    'feels_like': 17.87,
#    'temp_min': 18.53,
#    'temp_max': 19.52,
#    'pressure': 1010,
#    'sea_level': 1010,
#    'grnd_level': 1005,
#    'humidity': 55,
#    'temp_kf': -0.99},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 63},
#   'wind': {'speed': 3.81, 'deg': 282, 'gust': 5.11},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-14 12:00:00'},
#  {'dt': 1744642800,
#   'main': {'temp': 20.22,
#    'feels_like': 19.45,
#    'temp_min': 20.22,
#    'temp_max': 21.32,
#    'pressure': 1010,
#    'sea_level': 1010,
#    'grnd_level': 1004,
#    'humidity': 44,
#    'temp_kf': -1.1},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 68},
#   'wind': {'speed': 2.07, 'deg': 253, 'gust': 2.44},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-14 15:00:00'},
#  {'dt': 1744653600,
#   'main': {'temp': 17.22,
#    'feels_like': 16.28,
#    'temp_min': 17.22,
#    'temp_max': 17.22,
#    'pressure': 1010,
#    'sea_level': 1010,
#    'grnd_level': 1004,
#    'humidity': 49,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 48},
#   'wind': {'speed': 2.56, 'deg': 25, 'gust': 4.67},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-14 18:00:00'},
#  {'dt': 1744664400,
#   'main': {'temp': 16.08,
#    'feels_like': 15.21,
#    'temp_min': 16.08,
#    'temp_max': 16.08,
#    'pressure': 1010,
#    'sea_level': 1010,
#    'grnd_level': 1005,
#    'humidity': 56,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'clouds': {'all': 44},
#   'wind': {'speed': 2.96, 'deg': 70, 'gust': 6.91},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2025-04-14 21:00:00'},
#  {'dt': 1744675200,
#   'main': {'temp': 9.83,
#    'feels_like': 7.85,
#    'temp_min': 9.83,
#    'temp_max': 9.83,
#    'pressure': 1009,
#    'sea_level': 1009,
#    'grnd_level': 1003,
#    'humidity': 64,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'clouds': {'all': 37},
#   'wind': {'speed': 3.88, 'deg': 83, 'gust': 11.09},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2025-04-15 00:00:00'},
#  {'dt': 1744686000,
#   'main': {'temp': 12.55,
#    'feels_like': 11.71,
#    'temp_min': 12.55,
#    'temp_max': 12.55,
#    'pressure': 1008,
#    'sea_level': 1008,
#    'grnd_level': 1002,
#    'humidity': 71,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'clouds': {'all': 18},
#   'wind': {'speed': 3.82, 'deg': 89, 'gust': 9.64},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2025-04-15 03:00:00'},
#  {'dt': 1744696800,
#   'main': {'temp': 13.8,
#    'feels_like': 13.17,
#    'temp_min': 13.8,
#    'temp_max': 13.8,
#    'pressure': 1006,
#    'sea_level': 1006,
#    'grnd_level': 1000,
#    'humidity': 74,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 49},
#   'wind': {'speed': 4.52, 'deg': 87, 'gust': 10.98},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-15 06:00:00'},
#  {'dt': 1744707600,
#   'main': {'temp': 15.56,
#    'feels_like': 15,
#    'temp_min': 15.56,
#    'temp_max': 15.56,
#    'pressure': 1004,
#    'sea_level': 1004,
#    'grnd_level': 999,
#    'humidity': 70,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 67},
#   'wind': {'speed': 4.73, 'deg': 107, 'gust': 11.35},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-15 09:00:00'},
#  {'dt': 1744718400,
#   'main': {'temp': 14.73,
#    'feels_like': 14.3,
#    'temp_min': 14.73,
#    'temp_max': 14.73,
#    'pressure': 1004,
#    'sea_level': 1004,
#    'grnd_level': 998,
#    'humidity': 78,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 84},
#   'wind': {'speed': 5.86, 'deg': 117, 'gust': 12.21},
#   'visibility': 10000,
#   'pop': 0.2,
#   'rain': {'3h': 0.14},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-15 12:00:00'},
#  {'dt': 1744729200,
#   'main': {'temp': 14.14,
#    'feels_like': 13.83,
#    'temp_min': 14.14,
#    'temp_max': 14.14,
#    'pressure': 1003,
#    'sea_level': 1003,
#    'grnd_level': 997,
#    'humidity': 85,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 4.54, 'deg': 110, 'gust': 9.59},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-15 15:00:00'},
#  {'dt': 1744740000,
#   'main': {'temp': 13.64,
#    'feels_like': 13.36,
#    'temp_min': 13.64,
#    'temp_max': 13.64,
#    'pressure': 1003,
#    'sea_level': 1003,
#    'grnd_level': 997,
#    'humidity': 88,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 3.46, 'deg': 119, 'gust': 8.17},
#   'visibility': 10000,
#   'pop': 0.2,
#   'rain': {'3h': 0.22},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-15 18:00:00'},
#  {'dt': 1744750800,
#   'main': {'temp': 13.02,
#    'feels_like': 12.73,
#    'temp_min': 13.02,
#    'temp_max': 13.02,
#    'pressure': 1003,
#    'sea_level': 1003,
#    'grnd_level': 997,
#    'humidity': 90,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 2.13, 'deg': 129, 'gust': 5.22},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2025-04-15 21:00:00'},
#  {'dt': 1744761600,
#   'main': {'temp': 11.54,
#    'feels_like': 11.2,
#    'temp_min': 11.54,
#    'temp_max': 11.54,
#    'pressure': 1004,
#    'sea_level': 1004,
#    'grnd_level': 998,
#    'humidity': 94,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 92},
#   'wind': {'speed': 1.74, 'deg': 188, 'gust': 2.34},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2025-04-16 00:00:00'},
#  {'dt': 1744772400,
#   'main': {'temp': 11.32,
#    'feels_like': 10.96,
#    'temp_min': 11.32,
#    'temp_max': 11.32,
#    'pressure': 1005,
#    'sea_level': 1005,
#    'grnd_level': 1000,
#    'humidity': 94,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.73, 'deg': 238, 'gust': 2.16},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2025-04-16 03:00:00'},
#  {'dt': 1744783200,
#   'main': {'temp': 13,
#    'feels_like': 12.57,
#    'temp_min': 13,
#    'temp_max': 13,
#    'pressure': 1008,
#    'sea_level': 1008,
#    'grnd_level': 1002,
#    'humidity': 85,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 51},
#   'wind': {'speed': 1.99, 'deg': 230, 'gust': 3.69},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-16 06:00:00'},
#  {'dt': 1744794000,
#   'main': {'temp': 18.54,
#    'feels_like': 18.04,
#    'temp_min': 18.54,
#    'temp_max': 18.54,
#    'pressure': 1009,
#    'sea_level': 1009,
#    'grnd_level': 1004,
#    'humidity': 61,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 3},
#   'wind': {'speed': 1.9, 'deg': 312, 'gust': 2.87},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-16 09:00:00'},
#  {'dt': 1744804800,
#   'main': {'temp': 22.79,
#    'feels_like': 22.27,
#    'temp_min': 22.79,
#    'temp_max': 22.79,
#    'pressure': 1010,
#    'sea_level': 1010,
#    'grnd_level': 1004,
#    'humidity': 44,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'clouds': {'all': 18},
#   'wind': {'speed': 0.25, 'deg': 45, 'gust': 0.44},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-16 12:00:00'},
#  {'dt': 1744815600,
#   'main': {'temp': 23.39,
#    'feels_like': 22.86,
#    'temp_min': 23.39,
#    'temp_max': 23.39,
#    'pressure': 1009,
#    'sea_level': 1009,
#    'grnd_level': 1004,
#    'humidity': 41,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 6},
#   'wind': {'speed': 2.47, 'deg': 80, 'gust': 3.37},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-16 15:00:00'},
#  {'dt': 1744826400,
#   'main': {'temp': 20.55,
#    'feels_like': 20.12,
#    'temp_min': 20.55,
#    'temp_max': 20.55,
#    'pressure': 1009,
#    'sea_level': 1009,
#    'grnd_level': 1003,
#    'humidity': 56,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 37},
#   'wind': {'speed': 4.39, 'deg': 59, 'gust': 8.35},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-16 18:00:00'},
#  {'dt': 1744837200,
#   'main': {'temp': 18.38,
#    'feels_like': 18.13,
#    'temp_min': 18.38,
#    'temp_max': 18.38,
#    'pressure': 1008,
#    'sea_level': 1008,
#    'grnd_level': 1003,
#    'humidity': 71,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 96},
#   'wind': {'speed': 4.84, 'deg': 81, 'gust': 11.75},
#   'visibility': 10000,
#   'pop': 0.62,
#   'rain': {'3h': 0.33},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2025-04-16 21:00:00'},
#  {'dt': 1744848000,
#   'main': {'temp': 16.45,
#    'feels_like': 16.11,
#    'temp_min': 16.45,
#    'temp_max': 16.45,
#    'pressure': 1008,
#    'sea_level': 1008,
#    'grnd_level': 1002,
#    'humidity': 75,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 80},
#   'wind': {'speed': 3.81, 'deg': 101, 'gust': 11.45},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2025-04-17 00:00:00'},
#  {'dt': 1744858800,
#   'main': {'temp': 14.71,
#    'feels_like': 14.25,
#    'temp_min': 14.71,
#    'temp_max': 14.71,
#    'pressure': 1007,
#    'sea_level': 1007,
#    'grnd_level': 1002,
#    'humidity': 77,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'clouds': {'all': 12},
#   'wind': {'speed': 2.71, 'deg': 116, 'gust': 9.18},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2025-04-17 03:00:00'},
#  {'dt': 1744869600,
#   'main': {'temp': 15.07,
#    'feels_like': 14.54,
#    'temp_min': 15.07,
#    'temp_max': 15.07,
#    'pressure': 1008,
#    'sea_level': 1008,
#    'grnd_level': 1003,
#    'humidity': 73,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 43},
#   'wind': {'speed': 2.35, 'deg': 172, 'gust': 3.47},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-17 06:00:00'},
#  {'dt': 1744880400,
#   'main': {'temp': 15.87,
#    'feels_like': 15.39,
#    'temp_min': 15.87,
#    'temp_max': 15.87,
#    'pressure': 1010,
#    'sea_level': 1010,
#    'grnd_level': 1004,
#    'humidity': 72,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 83},
#   'wind': {'speed': 4.93, 'deg': 251, 'gust': 4.52},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-17 09:00:00'},
#  {'dt': 1744891200,
#   'main': {'temp': 11.79,
#    'feels_like': 11.06,
#    'temp_min': 11.79,
#    'temp_max': 11.79,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 1007,
#    'humidity': 78,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 90},
#   'wind': {'speed': 4.76, 'deg': 250, 'gust': 5.52},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-17 12:00:00'},
#  {'dt': 1744902000,
#   'main': {'temp': 10.82,
#    'feels_like': 9.99,
#    'temp_min': 10.82,
#    'temp_max': 10.82,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 1009,
#    'humidity': 78,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 3.98, 'deg': 266, 'gust': 5.09},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-17 15:00:00'},
#  {'dt': 1744912800,
#   'main': {'temp': 9.97,
#    'feels_like': 8.02,
#    'temp_min': 9.97,
#    'temp_max': 9.97,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 1009,
#    'humidity': 80,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 3.87, 'deg': 298, 'gust': 5.64},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-17 18:00:00'},
#  {'dt': 1744923600,
#   'main': {'temp': 9.75,
#    'feels_like': 8.75,
#    'temp_min': 9.75,
#    'temp_max': 9.75,
#    'pressure': 1016,
#    'sea_level': 1016,
#    'grnd_level': 1010,
#    'humidity': 81,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 2.19, 'deg': 299, 'gust': 2.71},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2025-04-17 21:00:00'},
#  {'dt': 1744934400,
#   'main': {'temp': 9.68,
#    'feels_like': 8.56,
#    'temp_min': 9.68,
#    'temp_max': 9.68,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 1010,
#    'humidity': 83,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 2.33, 'deg': 339, 'gust': 3},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2025-04-18 00:00:00'},
#  {'dt': 1744945200,
#   'main': {'temp': 10.01,
#    'feels_like': 9.21,
#    'temp_min': 10.01,
#    'temp_max': 10.01,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 1009,
#    'humidity': 82,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.53, 'deg': 2, 'gust': 2.17},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2025-04-18 03:00:00'},
#  {'dt': 1744956000,
#   'main': {'temp': 10.19,
#    'feels_like': 9.41,
#    'temp_min': 10.19,
#    'temp_max': 10.19,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 1010,
#    'humidity': 82,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.87, 'deg': 32, 'gust': 2.25},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-18 06:00:00'},
#  {'dt': 1744966800,
#   'main': {'temp': 11.79,
#    'feels_like': 10.98,
#    'temp_min': 11.79,
#    'temp_max': 11.79,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 1009,
#    'humidity': 75,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 0.91, 'deg': 22, 'gust': 0.81},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-18 09:00:00'},
#  {'dt': 1744977600,
#   'main': {'temp': 11.44,
#    'feels_like': 10.73,
#    'temp_min': 11.44,
#    'temp_max': 11.44,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 1009,
#    'humidity': 80,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 0.26, 'deg': 173, 'gust': 0.48},
#   'visibility': 10000,
#   'pop': 0.2,
#   'rain': {'3h': 0.22},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-18 12:00:00'},
#  {'dt': 1744988400,
#   'main': {'temp': 10.79,
#    'feels_like': 10.22,
#    'temp_min': 10.79,
#    'temp_max': 10.79,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 1008,
#    'humidity': 88,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.48, 'deg': 251, 'gust': 1.74},
#   'visibility': 10000,
#   'pop': 1,
#   'rain': {'3h': 1.28},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-18 15:00:00'},
#  {'dt': 1744999200,
#   'main': {'temp': 10.29,
#    'feels_like': 9.7,
#    'temp_min': 10.29,
#    'temp_max': 10.29,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 1009,
#    'humidity': 89,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.91, 'deg': 270, 'gust': 2.79},
#   'visibility': 10000,
#   'pop': 1,
#   'rain': {'3h': 0.22},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-18 18:00:00'},
#  {'dt': 1745010000,
#   'main': {'temp': 10.01,
#    'feels_like': 9.39,
#    'temp_min': 10.01,
#    'temp_max': 10.01,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 1008,
#    'humidity': 89,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.82, 'deg': 253, 'gust': 3},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2025-04-18 21:00:00'},
#  {'dt': 1745020800,
#   'main': {'temp': 9.67,
#    'feels_like': 8.95,
#    'temp_min': 9.67,
#    'temp_max': 9.67,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 1008,
#    'humidity': 88,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.83, 'deg': 263, 'gust': 3.64},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2025-04-19 00:00:00'},
#  {'dt': 1745031600,
#   'main': {'temp': 8.69,
#    'feels_like': 8.69,
#    'temp_min': 8.69,
#    'temp_max': 8.69,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 1007,
#    'humidity': 91,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.18, 'deg': 221, 'gust': 1.4},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2025-04-19 03:00:00'},
#  {'dt': 1745042400,
#   'main': {'temp': 9.81,
#    'feels_like': 9.27,
#    'temp_min': 9.81,
#    'temp_max': 9.81,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 1007,
#    'humidity': 84,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.66, 'deg': 191, 'gust': 2.44},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-19 06:00:00'},
#  {'dt': 1745053200,
#   'main': {'temp': 14.27,
#    'feels_like': 13.35,
#    'temp_min': 14.27,
#    'temp_max': 14.27,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 1006,
#    'humidity': 61,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.88, 'deg': 215, 'gust': 2.5},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-19 09:00:00'}]

# %% [markdown]
# Looks like the information we'll want is in `list`. Let's look at the first element of `list` to investigate further.

# %%
json["list"][-1]
# Out:
# {'dt': 1745053200,
#  'main': {'temp': 14.27,
#   'feels_like': 13.35,
#   'temp_min': 14.27,
#   'temp_max': 14.27,
#   'pressure': 1012,
#   'sea_level': 1012,
#   'grnd_level': 1006,
#   'humidity': 61,
#   'temp_kf': 0},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'clouds': {'all': 100},
#  'wind': {'speed': 1.88, 'deg': 215, 'gust': 2.5},
#  'visibility': 10000,
#  'pop': 0,
#  'sys': {'pod': 'd'},
#  'dt_txt': '2025-04-19 09:00:00'}

# %%
json["city"]
# Out:
# {'id': 6545310,
#  'name': 'Mitte',
#  'coord': {'lat': 52.52, 'lon': 13.405},
#  'country': 'DE',
#  'population': 329078,
#  'timezone': 7200,
#  'sunrise': 1744603832,
#  'sunset': 1744653738}

# %% [markdown]
# # Building a DataFrame

# %% [markdown]
# ## What would we like from the json?
# Let's begin by exploring the first 2 items of `list` and see what we have.

# %%
json["list"][0]
# Out:
# {'dt': 1744632000,
#  'main': {'temp': 18.53,
#   'feels_like': 17.87,
#   'temp_min': 18.53,
#   'temp_max': 19.52,
#   'pressure': 1010,
#   'sea_level': 1010,
#   'grnd_level': 1005,
#   'humidity': 55,
#   'temp_kf': -0.99},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'clouds': {'all': 63},
#  'wind': {'speed': 3.81, 'deg': 282, 'gust': 5.11},
#  'visibility': 10000,
#  'pop': 0,
#  'sys': {'pod': 'd'},
#  'dt_txt': '2025-04-14 12:00:00'}

# %%
json["list"][1]
# Out:
# {'dt': 1744642800,
#  'main': {'temp': 20.22,
#   'feels_like': 19.45,
#   'temp_min': 20.22,
#   'temp_max': 21.32,
#   'pressure': 1010,
#   'sea_level': 1010,
#   'grnd_level': 1004,
#   'humidity': 44,
#   'temp_kf': -1.1},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'clouds': {'all': 68},
#  'wind': {'speed': 2.07, 'deg': 253, 'gust': 2.44},
#  'visibility': 10000,
#  'pop': 0,
#  'sys': {'pod': 'd'},
#  'dt_txt': '2025-04-14 15:00:00'}

# %% [markdown]
# When deciding what is useful, remember the project goals.
#
# The time the forecast is for will be useful.

# %%
json["list"][0]["dt_txt"]
# Out:
# '2025-04-14 12:00:00'

# %% [markdown]
# The temperature will be useful. Scooters don't have heaters!

# %%
json["list"][0]["main"]["temp"]
# Out:
# 18.53

# %% [markdown]
# The forecast will be useful. Scooters don't have a roof!

# %%
json["list"][0]["weather"][0]["main"]
# Out:
# 'Clouds'

# %% [markdown]
# If it's been recently raining will be useful. Wet conditions will affect scooter rentals.

# %%
json["list"][0]["rain"]["3h"]
# Out:
#   Cell In[18], line 1
#     json["list"][0]["rain"]["3h"]dt_text, NONE
#                                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# > If you get an error on 'rain', it's because it hasn't rained in the last 3 hours. But we know this key exists, because we read the [docs](https://openweathermap.org/forecast5)

# %% [markdown]
# Wind speed will be useful. It's likely to affect whether people rent scooters or not.

# %%
json["list"][0]["wind"]["speed"]
# Out:
# 3.81

# %% [markdown]
# ## Bringing together our chosen items

# %%
json["list"]
# Out:
# [{'dt': 1744632000,
#   'main': {'temp': 18.53,
#    'feels_like': 17.87,
#    'temp_min': 18.53,
#    'temp_max': 19.52,
#    'pressure': 1010,
#    'sea_level': 1010,
#    'grnd_level': 1005,
#    'humidity': 55,
#    'temp_kf': -0.99},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 63},
#   'wind': {'speed': 3.81, 'deg': 282, 'gust': 5.11},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-14 12:00:00'},
#  {'dt': 1744642800,
#   'main': {'temp': 20.22,
#    'feels_like': 19.45,
#    'temp_min': 20.22,
#    'temp_max': 21.32,
#    'pressure': 1010,
#    'sea_level': 1010,
#    'grnd_level': 1004,
#    'humidity': 44,
#    'temp_kf': -1.1},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 68},
#   'wind': {'speed': 2.07, 'deg': 253, 'gust': 2.44},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-14 15:00:00'},
#  {'dt': 1744653600,
#   'main': {'temp': 17.22,
#    'feels_like': 16.28,
#    'temp_min': 17.22,
#    'temp_max': 17.22,
#    'pressure': 1010,
#    'sea_level': 1010,
#    'grnd_level': 1004,
#    'humidity': 49,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 48},
#   'wind': {'speed': 2.56, 'deg': 25, 'gust': 4.67},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-14 18:00:00'},
#  {'dt': 1744664400,
#   'main': {'temp': 16.08,
#    'feels_like': 15.21,
#    'temp_min': 16.08,
#    'temp_max': 16.08,
#    'pressure': 1010,
#    'sea_level': 1010,
#    'grnd_level': 1005,
#    'humidity': 56,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'clouds': {'all': 44},
#   'wind': {'speed': 2.96, 'deg': 70, 'gust': 6.91},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2025-04-14 21:00:00'},
#  {'dt': 1744675200,
#   'main': {'temp': 9.83,
#    'feels_like': 7.85,
#    'temp_min': 9.83,
#    'temp_max': 9.83,
#    'pressure': 1009,
#    'sea_level': 1009,
#    'grnd_level': 1003,
#    'humidity': 64,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'clouds': {'all': 37},
#   'wind': {'speed': 3.88, 'deg': 83, 'gust': 11.09},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2025-04-15 00:00:00'},
#  {'dt': 1744686000,
#   'main': {'temp': 12.55,
#    'feels_like': 11.71,
#    'temp_min': 12.55,
#    'temp_max': 12.55,
#    'pressure': 1008,
#    'sea_level': 1008,
#    'grnd_level': 1002,
#    'humidity': 71,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'clouds': {'all': 18},
#   'wind': {'speed': 3.82, 'deg': 89, 'gust': 9.64},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2025-04-15 03:00:00'},
#  {'dt': 1744696800,
#   'main': {'temp': 13.8,
#    'feels_like': 13.17,
#    'temp_min': 13.8,
#    'temp_max': 13.8,
#    'pressure': 1006,
#    'sea_level': 1006,
#    'grnd_level': 1000,
#    'humidity': 74,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 49},
#   'wind': {'speed': 4.52, 'deg': 87, 'gust': 10.98},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-15 06:00:00'},
#  {'dt': 1744707600,
#   'main': {'temp': 15.56,
#    'feels_like': 15,
#    'temp_min': 15.56,
#    'temp_max': 15.56,
#    'pressure': 1004,
#    'sea_level': 1004,
#    'grnd_level': 999,
#    'humidity': 70,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 67},
#   'wind': {'speed': 4.73, 'deg': 107, 'gust': 11.35},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-15 09:00:00'},
#  {'dt': 1744718400,
#   'main': {'temp': 14.73,
#    'feels_like': 14.3,
#    'temp_min': 14.73,
#    'temp_max': 14.73,
#    'pressure': 1004,
#    'sea_level': 1004,
#    'grnd_level': 998,
#    'humidity': 78,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 84},
#   'wind': {'speed': 5.86, 'deg': 117, 'gust': 12.21},
#   'visibility': 10000,
#   'pop': 0.2,
#   'rain': {'3h': 0.14},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-15 12:00:00'},
#  {'dt': 1744729200,
#   'main': {'temp': 14.14,
#    'feels_like': 13.83,
#    'temp_min': 14.14,
#    'temp_max': 14.14,
#    'pressure': 1003,
#    'sea_level': 1003,
#    'grnd_level': 997,
#    'humidity': 85,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 4.54, 'deg': 110, 'gust': 9.59},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-15 15:00:00'},
#  {'dt': 1744740000,
#   'main': {'temp': 13.64,
#    'feels_like': 13.36,
#    'temp_min': 13.64,
#    'temp_max': 13.64,
#    'pressure': 1003,
#    'sea_level': 1003,
#    'grnd_level': 997,
#    'humidity': 88,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 3.46, 'deg': 119, 'gust': 8.17},
#   'visibility': 10000,
#   'pop': 0.2,
#   'rain': {'3h': 0.22},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-15 18:00:00'},
#  {'dt': 1744750800,
#   'main': {'temp': 13.02,
#    'feels_like': 12.73,
#    'temp_min': 13.02,
#    'temp_max': 13.02,
#    'pressure': 1003,
#    'sea_level': 1003,
#    'grnd_level': 997,
#    'humidity': 90,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 2.13, 'deg': 129, 'gust': 5.22},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2025-04-15 21:00:00'},
#  {'dt': 1744761600,
#   'main': {'temp': 11.54,
#    'feels_like': 11.2,
#    'temp_min': 11.54,
#    'temp_max': 11.54,
#    'pressure': 1004,
#    'sea_level': 1004,
#    'grnd_level': 998,
#    'humidity': 94,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 92},
#   'wind': {'speed': 1.74, 'deg': 188, 'gust': 2.34},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2025-04-16 00:00:00'},
#  {'dt': 1744772400,
#   'main': {'temp': 11.32,
#    'feels_like': 10.96,
#    'temp_min': 11.32,
#    'temp_max': 11.32,
#    'pressure': 1005,
#    'sea_level': 1005,
#    'grnd_level': 1000,
#    'humidity': 94,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.73, 'deg': 238, 'gust': 2.16},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2025-04-16 03:00:00'},
#  {'dt': 1744783200,
#   'main': {'temp': 13,
#    'feels_like': 12.57,
#    'temp_min': 13,
#    'temp_max': 13,
#    'pressure': 1008,
#    'sea_level': 1008,
#    'grnd_level': 1002,
#    'humidity': 85,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 51},
#   'wind': {'speed': 1.99, 'deg': 230, 'gust': 3.69},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-16 06:00:00'},
#  {'dt': 1744794000,
#   'main': {'temp': 18.54,
#    'feels_like': 18.04,
#    'temp_min': 18.54,
#    'temp_max': 18.54,
#    'pressure': 1009,
#    'sea_level': 1009,
#    'grnd_level': 1004,
#    'humidity': 61,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 3},
#   'wind': {'speed': 1.9, 'deg': 312, 'gust': 2.87},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-16 09:00:00'},
#  {'dt': 1744804800,
#   'main': {'temp': 22.79,
#    'feels_like': 22.27,
#    'temp_min': 22.79,
#    'temp_max': 22.79,
#    'pressure': 1010,
#    'sea_level': 1010,
#    'grnd_level': 1004,
#    'humidity': 44,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'clouds': {'all': 18},
#   'wind': {'speed': 0.25, 'deg': 45, 'gust': 0.44},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-16 12:00:00'},
#  {'dt': 1744815600,
#   'main': {'temp': 23.39,
#    'feels_like': 22.86,
#    'temp_min': 23.39,
#    'temp_max': 23.39,
#    'pressure': 1009,
#    'sea_level': 1009,
#    'grnd_level': 1004,
#    'humidity': 41,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 6},
#   'wind': {'speed': 2.47, 'deg': 80, 'gust': 3.37},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-16 15:00:00'},
#  {'dt': 1744826400,
#   'main': {'temp': 20.55,
#    'feels_like': 20.12,
#    'temp_min': 20.55,
#    'temp_max': 20.55,
#    'pressure': 1009,
#    'sea_level': 1009,
#    'grnd_level': 1003,
#    'humidity': 56,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 37},
#   'wind': {'speed': 4.39, 'deg': 59, 'gust': 8.35},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-16 18:00:00'},
#  {'dt': 1744837200,
#   'main': {'temp': 18.38,
#    'feels_like': 18.13,
#    'temp_min': 18.38,
#    'temp_max': 18.38,
#    'pressure': 1008,
#    'sea_level': 1008,
#    'grnd_level': 1003,
#    'humidity': 71,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'clouds': {'all': 96},
#   'wind': {'speed': 4.84, 'deg': 81, 'gust': 11.75},
#   'visibility': 10000,
#   'pop': 0.62,
#   'rain': {'3h': 0.33},
#   'sys': {'pod': 'n'},
#   'dt_txt': '2025-04-16 21:00:00'},
#  {'dt': 1744848000,
#   'main': {'temp': 16.45,
#    'feels_like': 16.11,
#    'temp_min': 16.45,
#    'temp_max': 16.45,
#    'pressure': 1008,
#    'sea_level': 1008,
#    'grnd_level': 1002,
#    'humidity': 75,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 80},
#   'wind': {'speed': 3.81, 'deg': 101, 'gust': 11.45},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2025-04-17 00:00:00'},
#  {'dt': 1744858800,
#   'main': {'temp': 14.71,
#    'feels_like': 14.25,
#    'temp_min': 14.71,
#    'temp_max': 14.71,
#    'pressure': 1007,
#    'sea_level': 1007,
#    'grnd_level': 1002,
#    'humidity': 77,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'clouds': {'all': 12},
#   'wind': {'speed': 2.71, 'deg': 116, 'gust': 9.18},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2025-04-17 03:00:00'},
#  {'dt': 1744869600,
#   'main': {'temp': 15.07,
#    'feels_like': 14.54,
#    'temp_min': 15.07,
#    'temp_max': 15.07,
#    'pressure': 1008,
#    'sea_level': 1008,
#    'grnd_level': 1003,
#    'humidity': 73,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 43},
#   'wind': {'speed': 2.35, 'deg': 172, 'gust': 3.47},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-17 06:00:00'},
#  {'dt': 1744880400,
#   'main': {'temp': 15.87,
#    'feels_like': 15.39,
#    'temp_min': 15.87,
#    'temp_max': 15.87,
#    'pressure': 1010,
#    'sea_level': 1010,
#    'grnd_level': 1004,
#    'humidity': 72,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 83},
#   'wind': {'speed': 4.93, 'deg': 251, 'gust': 4.52},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-17 09:00:00'},
#  {'dt': 1744891200,
#   'main': {'temp': 11.79,
#    'feels_like': 11.06,
#    'temp_min': 11.79,
#    'temp_max': 11.79,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 1007,
#    'humidity': 78,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 90},
#   'wind': {'speed': 4.76, 'deg': 250, 'gust': 5.52},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-17 12:00:00'},
#  {'dt': 1744902000,
#   'main': {'temp': 10.82,
#    'feels_like': 9.99,
#    'temp_min': 10.82,
#    'temp_max': 10.82,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 1009,
#    'humidity': 78,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 3.98, 'deg': 266, 'gust': 5.09},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-17 15:00:00'},
#  {'dt': 1744912800,
#   'main': {'temp': 9.97,
#    'feels_like': 8.02,
#    'temp_min': 9.97,
#    'temp_max': 9.97,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 1009,
#    'humidity': 80,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 3.87, 'deg': 298, 'gust': 5.64},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-17 18:00:00'},
#  {'dt': 1744923600,
#   'main': {'temp': 9.75,
#    'feels_like': 8.75,
#    'temp_min': 9.75,
#    'temp_max': 9.75,
#    'pressure': 1016,
#    'sea_level': 1016,
#    'grnd_level': 1010,
#    'humidity': 81,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 2.19, 'deg': 299, 'gust': 2.71},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2025-04-17 21:00:00'},
#  {'dt': 1744934400,
#   'main': {'temp': 9.68,
#    'feels_like': 8.56,
#    'temp_min': 9.68,
#    'temp_max': 9.68,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 1010,
#    'humidity': 83,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 2.33, 'deg': 339, 'gust': 3},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2025-04-18 00:00:00'},
#  {'dt': 1744945200,
#   'main': {'temp': 10.01,
#    'feels_like': 9.21,
#    'temp_min': 10.01,
#    'temp_max': 10.01,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 1009,
#    'humidity': 82,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.53, 'deg': 2, 'gust': 2.17},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2025-04-18 03:00:00'},
#  {'dt': 1744956000,
#   'main': {'temp': 10.19,
#    'feels_like': 9.41,
#    'temp_min': 10.19,
#    'temp_max': 10.19,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 1010,
#    'humidity': 82,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.87, 'deg': 32, 'gust': 2.25},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-18 06:00:00'},
#  {'dt': 1744966800,
#   'main': {'temp': 11.79,
#    'feels_like': 10.98,
#    'temp_min': 11.79,
#    'temp_max': 11.79,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 1009,
#    'humidity': 75,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 0.91, 'deg': 22, 'gust': 0.81},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-18 09:00:00'},
#  {'dt': 1744977600,
#   'main': {'temp': 11.44,
#    'feels_like': 10.73,
#    'temp_min': 11.44,
#    'temp_max': 11.44,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 1009,
#    'humidity': 80,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 0.26, 'deg': 173, 'gust': 0.48},
#   'visibility': 10000,
#   'pop': 0.2,
#   'rain': {'3h': 0.22},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-18 12:00:00'},
#  {'dt': 1744988400,
#   'main': {'temp': 10.79,
#    'feels_like': 10.22,
#    'temp_min': 10.79,
#    'temp_max': 10.79,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 1008,
#    'humidity': 88,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.48, 'deg': 251, 'gust': 1.74},
#   'visibility': 10000,
#   'pop': 1,
#   'rain': {'3h': 1.28},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-18 15:00:00'},
#  {'dt': 1744999200,
#   'main': {'temp': 10.29,
#    'feels_like': 9.7,
#    'temp_min': 10.29,
#    'temp_max': 10.29,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 1009,
#    'humidity': 89,
#    'temp_kf': 0},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.91, 'deg': 270, 'gust': 2.79},
#   'visibility': 10000,
#   'pop': 1,
#   'rain': {'3h': 0.22},
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-18 18:00:00'},
#  {'dt': 1745010000,
#   'main': {'temp': 10.01,
#    'feels_like': 9.39,
#    'temp_min': 10.01,
#    'temp_max': 10.01,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 1008,
#    'humidity': 89,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.82, 'deg': 253, 'gust': 3},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2025-04-18 21:00:00'},
#  {'dt': 1745020800,
#   'main': {'temp': 9.67,
#    'feels_like': 8.95,
#    'temp_min': 9.67,
#    'temp_max': 9.67,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 1008,
#    'humidity': 88,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.83, 'deg': 263, 'gust': 3.64},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2025-04-19 00:00:00'},
#  {'dt': 1745031600,
#   'main': {'temp': 8.69,
#    'feels_like': 8.69,
#    'temp_min': 8.69,
#    'temp_max': 8.69,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 1007,
#    'humidity': 91,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.18, 'deg': 221, 'gust': 1.4},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2025-04-19 03:00:00'},
#  {'dt': 1745042400,
#   'main': {'temp': 9.81,
#    'feels_like': 9.27,
#    'temp_min': 9.81,
#    'temp_max': 9.81,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 1007,
#    'humidity': 84,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.66, 'deg': 191, 'gust': 2.44},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-19 06:00:00'},
#  {'dt': 1745053200,
#   'main': {'temp': 14.27,
#    'feels_like': 13.35,
#    'temp_min': 14.27,
#    'temp_max': 14.27,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 1006,
#    'humidity': 61,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 1.88, 'deg': 215, 'gust': 2.5},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2025-04-19 09:00:00'}]

# %%
json["list"][0]["rain"]["3h"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 json["list"][0]["rain"]["3h"]
#
# KeyError: 'rain'

# %%
json["list"][0].get("rain", {}).get("3h", None) #fallback NONE if it doesnt rain

# %%
weather_items = []

for item in json["list"]:
    weather_item = {
        "forecast_time": item.get("dt_txt", None),
        "temperature": item["main"].get("temp", None),
        "forecast": item["weather"][0].get("main", None),
        "rain_in_last_3h": item.get("rain", {}).get("3h", 0),
        "wind_speed": item["wind"].get("speed", None),
    }

    weather_items.append(weather_item)

weather_df = pd.DataFrame(weather_items)

weather_df.head()
# Out:
#          forecast_time  temperature forecast  rain_in_last_3h  wind_speed
# 0  2025-04-14 12:00:00        18.53   Clouds              0.0        3.81
# 1  2025-04-14 15:00:00        20.22   Clouds              0.0        2.07
# 2  2025-04-14 18:00:00        17.22   Clouds              0.0        2.56
# 3  2025-04-14 21:00:00        16.08   Clouds              0.0        2.96
# 4  2025-04-15 00:00:00         9.83   Clouds              0.0        3.88

# %% [markdown]
# The `rain` key in the JSON data is not always present. In the absence of this key, it's assumed that there hasn't been any recent rainfall. Since this key isn't always available, not encountering it during our loop can cause an error. To address this, we'll employ two `.get()` methods to handle the absence of the `rain` key.
#
# > **Remember:** The second parameter of `.get()` serves as a fallback value, which is inserted into our dictionary if the key we're looking for doesn't exist.
#
# The first `.get()` method checks for the existence of the `rain` key. If present, it will use the value associated with that key. If the `rain` key is missing, an empty dictionary will be used, preventing the code from breaking. The second `.get()` method checks for the `3h` key. If present, it will use its value. Otherwise, a default value of `0` will be used.

# %% [markdown]
# # Creating a function for multiple cities

# %%
city = "Berlin"
country = "DE"
API_key = "ef4ec8b06e1e2827304d5686b1b71364"

# %%
geo_url = (f"http://api.openweathermap.org/geo/1.0/direct?q={city},{country}&limit=5&appid={API_key}")
geo_response = requests.get(geo_url)
geo_json = geo_response.json()
latitude = geo_json[0]["lat"]
longitude = geo_json[0]["lon"]

# %%
geo_json[0]["lat"]
# Out:
# 52.5170365

# %%
import pandas as pd
from datetime import datetime
from pytz import timezone

def fetch_weather_data(cities):
  # Let's ensure the timezone is our local timezone
  berlin_timezone = timezone('Europe/Berlin')
  API_key = "ef4ec8b06e1e2827304d5686b1b71364"
  weather_items = []

  for city in cities:

    country = "DE"

    # Geocoder api to get the latitude and longitude
    # This information should be from your SQL table, but we don't have that here
    geo_url = (f"http://api.openweathermap.org/geo/1.0/direct?q={city},{country}&limit=5&appid={API_key}")
    geo_response = requests.get(geo_url)
    geo_json = geo_response.json()
    latitude = geo_json[0]["lat"]
    longitude = geo_json[0]["lon"]

    # weather api
    weather_url = (f"https://api.openweathermap.org/data/2.5/forecast?lat={latitude}&lon={longitude}&appid={API_key}&units=metric")
    weather_response = requests.get(weather_url)
    weather_json = weather_response.json()

    # Added the time retrieved so we know when the forecast was made
    retrieval_time = datetime.now(berlin_timezone).strftime("%Y-%m-%d %H:%M:%S")

    for item in weather_json["list"]:
        weather_item = {
            # Added the city name, so the information is clear when looking at multiple cities
            "city": city,
            "forecast_time": item.get("dt_txt", None),
            "temperature": item["main"].get("temp", None),
            "forecast": item["weather"][0].get("main", None),
            "rain_in_last_3h": item.get("rain", {}).get("3h", 0),
            "wind_speed": item["wind"].get("speed", None),
            "data_retrieved_at": retrieval_time
        }

        weather_items.append(weather_item)

  weather_df = pd.DataFrame(weather_items)

  return weather_df

# %%
fetch_weather_data(["Berlin", "Hamburg", "Munich"])
# Out:
#        city        forecast_time  temperature forecast  rain_in_last_3h  \
# 0    Berlin  2025-04-14 09:00:00        17.00     Rain             0.15
# 1    Berlin  2025-04-14 12:00:00        17.77   Clouds             0.00
# 2    Berlin  2025-04-14 15:00:00        19.88   Clouds             0.00
# 3    Berlin  2025-04-14 18:00:00        17.22   Clouds             0.00
# 4    Berlin  2025-04-14 21:00:00        16.08   Clouds             0.00
# ..      ...                  ...          ...      ...              ...
# 115  Munich  2025-04-18 18:00:00         9.37   Clouds             0.00
# 116  Munich  2025-04-18 21:00:00         8.75   Clouds             0.00
# 117  Munich  2025-04-19 00:00:00         8.47   Clouds             0.00
# 118  Munich  2025-04-19 03:00:00         8.10   Clouds             0.00
# 119  Munich  2025-04-19 06:00:00         9.22   Clouds             0.00
#
#      wind_speed    data_retrieved_at
# 0          3.52  2025-04-14 10:28:51
# 1          3.81  2025-04-14 10:28:51
# 2          2.07  2025-04-14 10:28:51
# 3          2.56  2025-04-14 10:28:51
# 4          2.96  2025-04-14 10:28:51
# ..          ...                  ...
# 115        1.00  2025-04-14 10:28:51
# 116        1.57  2025-04-14 10:28:51
# 117        1.55  2025-04-14 10:28:51
# 118        1.40  2025-04-14 10:28:51
# 119        1.22  2025-04-14 10:28:51
#
# [120 rows x 7 columns]

# %% [markdown]
# # Making our function work with our SQL cities data
# This section delves into a more advanced aspect of the project, which may be beyond the point many of you got to. However, it serves as an illustrative example of how to structure your work effectively. It demonstrates how we can compartmentalise various aspects of our data processing pipeline into distinct functions, enhancing code readability and facilitating debugging.
# > This part will only work locally, not on colab. You must also create your weather table in SQL first.

# %%
import pandas as pd
import requests
from pytz import timezone
from datetime import datetime

def retrieve_and_send_data():
  connection_string = create_connection_string()
  cities_df = fetch_cities_data(connection_string)
  weather_df = fetch_weather_data(cities_df)
  store_weather_data(weather_df, connection_string)
  return "Data has been updated"

def create_connection_string():
  schema = "gans"
  host = "127.0.0.1"
  user = "root"
  password = "YOUR_PASSWORD_HERE"
  port = 3306
  return f'mysql+pymysql://{user}:{password}@{host}:{port}/{schema}'

def fetch_cities_data(connection_string):
  return pd.read_sql("cities", con=connection_string)

def fetch_weather_data(cities_df):
  berlin_timezone = timezone('Europe/Berlin')
  API_key = 'YOUR_API_HERE'
  weather_items = []

  for _, city in cities_df.iterrows():
      latitude = city["latitude"]
      longitude = city["longitude"]
      city_id = city["city_id"]

      url = (f"https://api.openweathermap.org/data/2.5/forecast?lat={latitude}&lon={longitude}&appid={API_key}&units=metric")
      response = requests.get(url)
      weather_data = response.json()

      retrieval_time = datetime.now(berlin_timezone).strftime("%Y-%m-%d %H:%M:%S")

      for item in weather_data["list"]:
          weather_item = {
              "city_id": city_id,
              "forecast_time": item.get("dt_txt"),
              "temperature": item["main"].get("temp"),
              "forecast": item["weather"][0].get("main"),
              "rain_in_last_3h": item.get("rain", {}).get("3h", 0),
              "wind_speed": item["wind"].get("speed"),
              "data_retrieved_at": retrieval_time
          }
          weather_items.append(weather_item)

  weather_df = pd.DataFrame(weather_items)
  weather_df["forecast_time"] = pd.to_datetime(weather_df["forecast_time"])
  weather_df["data_retrieved_at"] = pd.to_datetime(weather_df["data_retrieved_at"])

  return weather_df

def store_weather_data(weather_df, connection_string):
  weather_df.to_sql('weather',
                    if_exists='append',
                    con=connection_string,
                    index=False)

# %%
retrieve_and_send_data()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-17-5aa6b324b501> in <cell line: 0>()
# ----> 1 retrieve_and_send_data()
#
# <ipython-input-9-03a815b274b3> in retrieve_and_send_data()
#       6 def retrieve_and_send_data():
#       7   connection_string = create_connection_string()
# ----> 8   cities_df = fetch_cities_data(connection_string)
#       9   weather_df = fetch_weather_data(cities_df)
#      10   store_weather_data(weather_df, connection_string)
#
# <ipython-input-9-03a815b274b3> in fetch_cities_data(connection_string)
#      20
#      21 def fetch_cities_data(connection_string):
# ---> 22   return pd.read_sql("cities", con=connection_string)
#      23
#      24 def fetch_weather_data(cities_df):
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     702     assert dtype_backend is not lib.no_default
#     703
# --> 704     with pandasSQL_builder(con) as pandas_sql:
#     705         if isinstance(pandas_sql, SQLiteDatabase):
#     706             return pandas_sql.read_query(
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in pandasSQL_builder(con, schema, need_transaction)
#     904
#     905     if sqlalchemy is not None and isinstance(con, (str, sqlalchemy.engine.Connectable)):
# --> 906         return SQLDatabase(con, schema, need_transaction)
#     907
#     908     adbc = import_optional_dependency("adbc_driver_manager.dbapi", errors="ignore")
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/sql.py in __init__(self, con, schema, need_transaction)
#    1631         self.exit_stack = ExitStack()
#    1632         if isinstance(con, str):
# -> 1633             con = create_engine(con)
#    1634             self.exit_stack.callback(con.dispose)
#    1635         if isinstance(con, Engine):
#
# /usr/local/lib/python3.11/dist-packages/sqlalchemy/engine/create.py in create_engine(url, **kwargs)
#
# /usr/local/lib/python3.11/dist-packages/sqlalchemy/util/deprecations.py in warned(fn, *args, **kwargs)
#     279                         stacklevel=3,
#     280                     )
# --> 281             return fn(*args, **kwargs)  # type: ignore[no-any-return]
#     282
#     283         doc = fn.__doc__ is not None and fn.__doc__ or ""
#
# /usr/local/lib/python3.11/dist-packages/sqlalchemy/engine/create.py in create_engine(url, **kwargs)
#     600             if k in kwargs:
#     601                 dbapi_args[k] = pop_kwarg(k)
# --> 602         dbapi = dbapi_meth(**dbapi_args)
#     603
#     604     dialect_args["dbapi"] = dbapi
#
# /usr/local/lib/python3.11/dist-packages/sqlalchemy/dialects/mysql/pymysql.py in import_dbapi(cls)
#      72     @classmethod
#      73     def import_dbapi(cls):
# ---> 74         return __import__("pymysql")
#      75
#      76     @langhelpers.memoized_property
#
# ModuleNotFoundError: No module named 'pymysql'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
